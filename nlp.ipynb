# %% [markdown]
# ## Stemming

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# ## PorterStemmer

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()

# %%
for word in words:
    print(word+"--->"+ps.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->histori
# finally--->final
# finalized--->final

# %%
ps.stem('Congratulations')
# Out:
# 'congratul'

# %%
ps.stem('sitting')
# Out:
# 'sit'

# %% [markdown]
# ## RegexpStemmer Class

# %%
from nltk.stem import RegexpStemmer
rs=RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
rs.stem('eating')
# Out:
# 'eat'

# %%
rs.stem('ingeating')
# Out:
# 'ingeat'

# %% [markdown]
# ## Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer
ss=SnowballStemmer(language='english')

# %%
for word in words:
    print(word+"--->"+ss.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->histori
# finally--->final
# finalized--->final

# %%
ps.stem('fairly'),ss.stem('fairly')
# Out:
# ('fairli', 'fair')

# %%
ps.stem('sportingly'),ss.stem('sportingly')
# Out:
# ('sportingli', 'sport')

# %%
# Sometimes give bad results also
ss.stem('goes'),ps.stem('goes')
# Out:
# ('goe', 'goe')

# %%
ps
