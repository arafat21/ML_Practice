# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_index = pd.read_csv("economic_index.csv")

# %%
df_index.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %% [markdown]
# ### Drop Unnecessary Columns

# %%
df_index.drop(columns=['Unnamed: 0','year','month'],axis=1,inplace=True)

# %%
df_index.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %% [markdown]
# ### Check  Null Values

# %%
df_index.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %% [markdown]
# ### Some visualization

# %%
import seaborn as sns
sns.pairplot(df_index)

# %%
df_index.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %% [markdown]
# ### Visualize the datapoints more closely

# %%
plt.scatter(df_index['interest_rate'],df_index['unemployment_rate'],color='r')

# %% [markdown]
# ### Independent and Dependent Feature

# %%
X = df_index.iloc[:,:-1] ## select all rows(:), select all columns except last(:-1)
y = df_index.iloc[:,-1] ## select all rows(:), select only last column(-1)

# %%
X.head()
# Out:
#    interest_rate  unemployment_rate
# 0           2.75                5.3
# 1           2.50                5.3
# 2           2.50                5.3
# 3           2.50                5.3
# 4           2.50                5.4

# %%
y
# Out:
# 0     1464
# 1     1394
# 2     1357
# 3     1293
# 4     1256
# 5     1254
# 6     1234
# 7     1195
# 8     1159
# 9     1167
# 10    1130
# 11    1075
# 12    1047
# 13     965
# 14     943
# 15     958
# 16     971
# 17     949
# 18     884
# 19     866
# 20     876
# 21     822
# 22     704
# 23     719
# Name: index_price, dtype: int64

# %% [markdown]
# ### Train Test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state =42)

# %%
sns.regplot(x=df_index['interest_rate'],y=df_index['index_price'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='index_price'>

# %%
sns.regplot(x=df_index['interest_rate'],y=df_index['unemployment_rate'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='unemployment_rate'>

# %%
sns.regplot(x=df_index['index_price'],y=df_index['unemployment_rate'])
# Out:
# <Axes: xlabel='index_price', ylabel='unemployment_rate'>

# %% [markdown]
# ## Scalar fit Transform

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-0.90115511,  0.37908503],
#        [ 1.31077107, -1.48187786],
#        [-0.90115511,  1.30956648],
#        [ 1.31077107, -0.55139641],
#        [ 1.31077107, -1.48187786],
#        [-0.16384638,  0.68924552],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -1.48187786],
#        [ 1.31077107, -1.17171738],
#        [-0.90115511,  1.30956648],
#        [-0.90115511,  0.999406  ],
#        [-0.90115511,  0.37908503],
#        [-0.90115511,  0.999406  ],
#        [ 0.57346234, -0.8615569 ],
#        [-0.16384638, -0.24123593],
#        [-0.90115511,  0.06892455],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -0.8615569 ]])

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score
validation_score = cross_val_score(regression,X_train,y_train,scoring='neg_mean_squared_error',cv=3)

# %%
np.mean(validation_score)
# Out:
# np.float64(-5914.828180162392)

# %% [markdown]
# ### Prediction

# %%
y_pred = regression.predict(X_test)

# %%
y_pred
# Out:
# array([1180.7466813 ,  802.74279699, 1379.83457045,  838.52599602,
#         973.85313963, 1144.96348227])

# %% [markdown]
# ### Performance Metrices

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
y_test
# Out:
# array([[ 0.36115756, -0.82078268],
#        [-1.08347268,  1.33377186],
#        [ 1.8057878 , -1.43636969],
#        [-1.08347268,  1.02597835],
#        [-0.36115756,  0.41039134],
#        [ 0.36115756, -0.51298918]])

# %%
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
rmse = np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 mse = mean_squared_error(y_test,y_pred)
#       2 mae = mean_absolute_error(y_test,y_pred)
#       3 rmse = np.sqrt(mse)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_regression.py:579, in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     529 """Mean squared error regression loss.
#     530
#     531 Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)    575 0.825...
#     576 """
#     577 xp, _ = get_namespace(y_true, y_pred, sample_weight, multioutput)
#     578 _, y_true, y_pred, sample_weight, multioutput = (
# --> 579     _check_reg_targets_with_floating_dtype(
#     580         y_true, y_pred, sample_weight, multioutput, xp=xp
#     581     )
#     582 )
#     583 output_errors = _average(
#     584     (y_true - y_pred) ** 2, axis=0, weights=sample_weight, xp=xp
#     585 )
#     587 if isinstance(multioutput, str):
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_regression.py:208, in _check_reg_targets_with_floating_dtype(y_true, y_pred, sample_weight, multioutput, xp)
#     159 """Ensures y_true, y_pred, and sample_weight correspond to same regression task.
#     160
#     161 Extends `_check_reg_targets` by automatically selecting a suitable floating-point
#    (...)    204     correct keyword.
#     205 """
#     206 dtype_name = _find_matching_floating_dtype(y_true, y_pred, sample_weight, xp=xp)
# --> 208 y_type, y_true, y_pred, sample_weight, multioutput = _check_reg_targets(
#     209     y_true, y_pred, sample_weight, multioutput, dtype=dtype_name, xp=xp
#     210 )
#     212 return y_type, y_true, y_pred, sample_weight, multioutput
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_regression.py:126, in _check_reg_targets(y_true, y_pred, sample_weight, multioutput, dtype, xp)
#     123     y_pred = xp.reshape(y_pred, (-1, 1))
#     125 if y_true.shape[1] != y_pred.shape[1]:
# --> 126     raise ValueError(
#     127         "y_true and y_pred have different number of output ({0}!={1})".format(
#     128             y_true.shape[1], y_pred.shape[1]
#     129         )
#     130     )
#     132 n_outputs = y_true.shape[1]
#     133 allowed_multioutput_str = ("raw_values", "uniform_average", "variance_weighted")
#
# ValueError: y_true and y_pred have different number of output (2!=1)
